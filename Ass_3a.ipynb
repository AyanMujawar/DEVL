# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("C:/Users/Lenovo/Downloads/loan_applicants_sample.csv")

print("Dataset Head:\n", data.head())
# Out:
# Dataset Head:
#     ApplicantIncome  LoanAmount  Gender Married Dependents     Education  \
# 0             5000         200    Male     Yes          0      Graduate
# 1             3000         150  Female      No          1      Graduate
# 2             4000         120    Male     Yes          2  Not Graduate
# 3             2500         100  Female      No          0      Graduate
# 4             6000         250    Male     Yes         3+      Graduate
#
#   Self_Employed  Credit_History Property_Area Loan_Status
# 0            No               1         Urban           Y
# 1            No               0         Rural           N
# 2           Yes               1     Semiurban           Y
# 3            No               1         Urban           Y
# 4            No               0         Rural           N

# %%
# Checking for missing values
print("\nMissing values in the dataset:\n", data.isnull().sum())

# %%
data['LoanAmount'].fillna(data['LoanAmount'].mean(), inplace=True)

#data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mode()[0], inplace=True)

data['Credit_History'].fillna(data['Credit_History'].mode()[0], inplace=True)

for column in ['Gender', 'Married', 'Dependents', 'Self_Employed']:
    data[column].fillna(data[column].mode()[0], inplace=True)

print("\nSummary Statistics:\n", data.describe())
# Out:
# Summary Statistics:
#         ApplicantIncome  LoanAmount  Credit_History
# count         5.000000    5.000000        5.000000
# mean       4100.000000  164.000000        0.600000
# std        1431.782106   61.073726        0.547723
# min        2500.000000  100.000000        0.000000
# 25%        3000.000000  120.000000        0.000000
# 50%        4000.000000  150.000000        1.000000
# 75%        5000.000000  200.000000        1.000000
# max        6000.000000  250.000000        1.000000
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10104\3679691509.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['LoanAmount'].fillna(data['LoanAmount'].mean(), inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10104\3679691509.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Credit_History'].fillna(data['Credit_History'].mode()[0], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10104\3679691509.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mode()[0], inplace=True)

# %%
plt.figure(figsize=(18, 6))

plt.subplot(1, 2, 1)
sns.histplot(data['ApplicantIncome'], kde=True, color='blue')
plt.title('Distribution of Applicant Income')
# Out:
# Text(0.5, 1.0, 'Distribution of Applicant Income')

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 2)
sns.histplot(data['LoanAmount'], kde=True, color='green')
plt.title('Distribution of Loan Amount')

plt.tight_layout()
plt.show()

# %%
# Count plot for Loan Status
plt.figure(figsize=(6, 4))
sns.countplot(x='Loan_Status', data=data, palette='Set2')
plt.title('Loan Status Count')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10104\15677007.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Loan_Status', data=data, palette='Set2')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Property_Area', data=data, palette='Set1')
plt.title('Property Area Distribution')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10104\1660418569.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Property_Area', data=data, palette='Set1')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', data=data, palette='Set3')
plt.title('Gender Distribution')
plt.show()
